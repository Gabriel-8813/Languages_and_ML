# %% [markdown]
# #  1. Data Collection:

# %%
# Import Dependancies

import requests
import pandas as pd
from bs4 import BeautifulSoup
import re

# %%
#Read data from ready-to-use csv files, into dataframes

duolingo_df = pd.read_csv("Resources/duolingo_language_report_by_country.csv")
unpopulation_df = pd.read_csv("Resources/unpopulation.csv")
all_endangered_lang_df = pd.read_csv("Resources/clean_data.csv")
widely_spoken_lan_df = pd.read_csv("Resources/languages_by_total_speakers.csv")

# %%
#Check the dataframes

print(f"{duolingo_df.head()}")
print(f"{unpopulation_df.head()}")
print(f"{all_endangered_lang_df.head()}")
print(f"{widely_spoken_lan_df.head()}")
# Out:
#        country pop1_2020 pop2_2020 pop1_2021 pop2_2021 pop1_2022 pop2_2022  \
# 0  Afghanistan   English   Spanish   English   Turkish    German   English
# 1      Albania    German   English    German   English    German   English
# 2      Algeria   English    French   English    French   English    French
# 3      Andorra   English    French   English    French   English    French
# 4       Angola   English    French   English    French   English    French
#
#   pop1_2023 pop2_2023 pop1_2024 pop2_2024
# 0   English    German   English    German
# 1    German   English   English    German
# 2   English    French   English    French
# 3   English    French   English   Spanish
# 4   English    French   English    French
#    IndicatorId                            IndicatorName  \
# 0           46  Population by 5-year age groups and sex
# 1           46  Population by 5-year age groups and sex
# 2           46  Population by 5-year age groups and sex
# 3           46  Population by 5-year age groups and sex
# 4           46  Population by 5-year age groups and sex
#
#                                   IndicatorShortName  \
# 0  Annual population by 5-year age groups and by sex
# 1  Annual population by 5-year age groups and by sex
# 2  Annual population by 5-year age groups and by sex
# 3  Annual population by 5-year age groups and by sex
# 4  Annual population by 5-year age groups and by sex
#
#                        Source  SourceYear                              Author  \
# 0  World Population Prospects        2024  United Nations Population Division
# 1  World Population Prospects        2024  United Nations Population Division
# 2  World Population Prospects        2024  United Nations Population Division
# 3  World Population Prospects        2024  United Nations Population Division
# 4  World Population Prospects        2024  United Nations Population Division
#
#    LocationId     Location Iso2 Iso3  ...  AgeStart  AgeEnd  Age CategoryId  \
# 0           4  Afghanistan   AF  AFG  ...         0       4  0-4          0
# 1           4  Afghanistan   AF  AFG  ...         0       4  0-4          0
# 2           4  Afghanistan   AF  AFG  ...         0       4  0-4          0
# 3           4  Afghanistan   AF  AFG  ...         0       4  0-4          0
# 4           4  Afghanistan   AF  AFG  ...         0       4  0-4          0
#
#          Category EstimateTypeId           EstimateType  EstimateMethodId  \
# 0  Not applicable              1  Model-based Estimates                 3
# 1  Not applicable              1  Model-based Estimates                 3
# 2  Not applicable              1  Model-based Estimates                 3
# 3  Not applicable              1  Model-based Estimates                 3
# 4  Not applicable              1  Model-based Estimates                 3
#
#    EstimateMethod      Value
# 0      Projection  5896313.0
# 1      Projection  5989420.0
# 2      Projection  6099779.0
# 3      Projection  6218637.5
# 4      Projection  6341465.5
#
# [5 rows x 27 columns]
#    Unnamed: 0    ID Name in English  \
# 0           0  1022   South Italian
# 1           1  1023        Sicilian
# 2           2   383       Low Saxon
# 3           3   335      Belarusian
# 4           4   382         Lombard
#
#                                            Countries Degree of endangerment  \
# 0                                              Italy             Vulnerable
# 1                                              Italy             Vulnerable
# 2  Germany, Denmark, Netherlands, Poland, Russian...             Vulnerable
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...             Vulnerable
# 4                                 Italy, Switzerland  Definitely endangered
#
#    Number of speakers  Latitude  Longitude  \
# 0           7500000.0   40.9798    15.2490
# 1           5000000.0   37.4399    14.5019
# 2           4800000.0   53.4029    10.3601
# 3           4000000.0   53.9560    27.5756
# 4           3500000.0   45.7215     9.3273
#
#                          Description of the location
# 0  Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 1  Sicily (Sicilia), southern and central Calabri...
# 2  northern Germany, the north-eastern part of th...
# 3  Belarus except the Polesian-speaking south-wes...
# 4  the region of Lombardy (except the southernmos...
#                                             Language         Family  \
# 0                     English(excl.creole languages)  Indo-European
# 1  Mandarin Chinese(incl.Standard Chinese, but ex...   Sino-Tibetan
# 2                                   Hindi(excl.Urdu)  Indo-European
# 3                     Spanish(excl.creole languages)  Indo-European
# 4              Modern Standard Arabic(excl.dialects)   Afro-Asiatic
#
#        Branch First-language (L1) speakers Second-language (L2) speakers  \
# 0    Germanic                  380 million                 1.135 billion
# 1     Sinitic                  941 million                   199 million
# 2  Indo-Aryan                  345 million                   264 million
# 3     Romance                  486 million                    74 million
# 4     Semitic                         0[a]                   332 million
#
#   Total speakers (L1+L2)
# 0          1.515 billion
# 1          1.140 billion
# 2            609 million
# 3            560 million
# 4            332 million

# %%
# Use BeautifulSoup for scraping data about Languages_used_on_Internet_websites

# Wikipedia URL
url1 = "https://en.wikipedia.org/wiki/Languages_used_on_the_Internet"

# Fetch the webpage
response = requests.get(url1)
soup = BeautifulSoup(response.text, "html.parser")

# Find the correct table
table = soup.find("table", {"class": "wikitable"})

# Extract table rows
data = []
for row in table.find_all("tr")[1:]:  # Skip header row
    cols = row.find_all("td")
    if len(cols) >= 4:  # Ensure at least 4 columns exist
        language = cols[1].get_text(strip=True)  # Second column: language
        websites_usage = cols[3].get_text(strip=True)  # Fourth column: websites_usage as of Jan 2025

        data.append([language, websites_usage])

# Convert to DataFrame
df_languages_internet = pd.DataFrame(data, columns=["Language", "Websites_usage (%)"])

# Save to CSV
df_languages_internet.to_csv("Resources/content languages for websites (Jan 2025).csv", index=False)

print(f"Scraped {len(df_languages_internet)} languages")

# Display first few rows
df_languages_internet.head()
# Out:
# Scraped 38 languages
#   Language Websites_usage (%)
# 0  English              49.3%
# 1  Spanish               6.0%
# 2  Russian               3.9%
# 3   German               5.6%
# 4   French               4.4%

# %%
# Use BeautifulSoup for scraping data about official_languages_by_country

# Wikipedia URL
url2 = "https://en.wikipedia.org/wiki/List_of_official_languages_by_country_and_territory"

# Fetch the webpage
response = requests.get(url2)
soup = BeautifulSoup(response.text, "html.parser")

# Find the first table (it contains the country-language data)
table = soup.find("table", {"class": "wikitable"})

# Extract table data
data = []
for row in table.find_all("tr")[1:]:  # Skip the header row
    cols = row.find_all("td")
    if len(cols) >= 2:
        country = cols[0].get_text(strip=True)  # First column: Country
        languages = cols[2].get_text("\n", strip=True)  # Second column: Official Languages (preserve line breaks)

        # Split languages by new lines 
        for lang in languages.split("\n"):
            # Remove numbering (e.g., "1. English" → "English")
            lang_cleaned = re.sub(r"^\d+\.\s*", "", lang).strip()
            if lang_cleaned:  # Only add non-empty values
                data.append([country, lang_cleaned])

# Convert to DataFrame
df_languages = pd.DataFrame(data, columns=["Country", "Official Language"])

# Save to CSV
df_languages.to_csv("Resources/country_per_official_language.csv", index=False)

print(f"Scraped {len(df_languages)} country_per_official_language'")

# Display first few rows
df_languages.head()
# Out:
# Scraped 532 country_per_official_language'
#           Country Official Language
# 0     Abkhazia[a]            Abkhaz
# 1     Abkhazia[a]           Russian
# 2  Afghanistan[1]    Persian (Dari)
# 3  Afghanistan[1]            Pashto
# 4      Albania[2]          Albanian

# %%
# Use BeautifulSoup for scraping data about countries_by_population_growth_rate

# URL of the Wikipedia page
url3 = 'https://en.wikipedia.org/wiki/List_of_countries_by_population_growth_rate'

# Send a GET request to the URL
response = requests.get(url3)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all tables on the page
    tables = soup.find_all('table', {'class': 'wikitable'})

    if tables:
        
        table = tables[0]
        
        # Initialize lists to store the country names and percentage rates
        countries = []
        growth_rates = []

        # Iterate over the rows of the table
        for row in table.find_all('tr')[1:]:  # Skip the header row
            cells = row.find_all(['th', 'td'])
            if len(cells) > 1:
                country = cells[0].get_text(strip=True)  # Scrape country names
                growth_rate = cells[1].get_text(strip=True)  # Scrape growth rates
                countries.append(country)
                growth_rates.append(growth_rate)
        
        # Create a DataFrame from the lists
        pop_growth_df = pd.DataFrame({
            'Country': countries,
            'Growth Rate (%)': growth_rates
        })

        # Save the DataFrame to a CSV file
        pop_growth_df.to_csv('Resources/population_growth_rates.csv', index=False)



pop_growth_df = pop_growth_df.iloc[2:].reset_index(drop=True)

# Remove the star symbol from the country names
pop_growth_df['Country'] = pop_growth_df['Country'].str.replace('*', '', regex=False)

# Display the DataFrame
pop_growth_df.head()
# Out:
#        Country Growth Rate (%)
# 0  Afghanistan            2.22
# 1     Albania             0.16
# 2     Algeria             1.54
# 3     Andorra            -0.12
# 4      Angola             3.33

# %% [markdown]
# #  2. Data Cleaning & Pre-processing:

# %% [markdown]
# ### A. Widely spoken languages dataset

# %%
# Drop the unnecessary columns

widely_spoken_lan_df = widely_spoken_lan_df.drop(columns=['Family', 'Branch', 'First-language (L1) speakers', 'Second-language (L2) speakers'])

# Display the DataFrame to check the changes

widely_spoken_lan_df.head()
# Out:
#                                             Language Total speakers (L1+L2)
# 0                     English(excl.creole languages)          1.515 billion
# 1  Mandarin Chinese(incl.Standard Chinese, but ex...          1.140 billion
# 2                                   Hindi(excl.Urdu)            609 million
# 3                     Spanish(excl.creole languages)            560 million
# 4              Modern Standard Arabic(excl.dialects)            332 million

# %%
# Correct column name

widely_spoken_lan_df.rename(columns={"Total speakers (L1+L2)": "Total_Speakers"}, inplace=True)

#Check df changes

widely_spoken_lan_df.head()
# Out:
#                                             Language Total_Speakers
# 0                     English(excl.creole languages)  1.515 billion
# 1  Mandarin Chinese(incl.Standard Chinese, but ex...  1.140 billion
# 2                                   Hindi(excl.Urdu)    609 million
# 3                     Spanish(excl.creole languages)    560 million
# 4              Modern Standard Arabic(excl.dialects)    332 million

# %%
#convert Total_Speakers values  to numbers

def convert_speaker_count(value):
    if isinstance(value, str):
        value = value.lower().replace(" billion", "e9").replace(" million", "e6")
        return float(eval(value))  # Convert string to float
    return value

widely_spoken_lan_df["Total_Speakers"] = widely_spoken_lan_df["Total_Speakers"].apply(convert_speaker_count)

#Check df changes

widely_spoken_lan_df.head()
# Out:
#                                             Language  Total_Speakers
# 0                     English(excl.creole languages)    1.515000e+09
# 1  Mandarin Chinese(incl.Standard Chinese, but ex...    1.140000e+09
# 2                                   Hindi(excl.Urdu)    6.090000e+08
# 3                     Spanish(excl.creole languages)    5.600000e+08
# 4              Modern Standard Arabic(excl.dialects)    3.320000e+08

# %%
# Fill Missing Values with an estimated number 1000

widely_spoken_lan_df["Total_Speakers"] = widely_spoken_lan_df["Total_Speakers"].fillna(1000)

#Check df changes

widely_spoken_lan_df
# Out:
#                                              Language  Total_Speakers
# 0                      English(excl.creole languages)    1.515000e+09
# 1   Mandarin Chinese(incl.Standard Chinese, but ex...    1.140000e+09
# 2                                    Hindi(excl.Urdu)    6.090000e+08
# 3                      Spanish(excl.creole languages)    5.600000e+08
# 4               Modern Standard Arabic(excl.dialects)    3.320000e+08
# 5                       French(excl.creole languages)    3.120000e+08
# 6                                             Bengali    2.780000e+08
# 7                   Portuguese(excl.creole languages)    2.640000e+08
# 8                                             Russian    2.550000e+08
# 9                                    Urdu(excl.Hindi)    2.380000e+08
# 10                       Indonesian(excl. otherMalay)    1.990000e+08
# 11                                    Standard German    1.340000e+08
# 12                                           Japanese    1.230000e+08
# 13                                    Nigerian Pidgin    1.210000e+08
# 14        Egyptian Arabic(excl.other Arabic dialects)    1.030000e+08
# 15                                            Marathi    9.900000e+07
# 16                                             Telugu    9.600000e+07
# 17                                            Turkish    9.000000e+07
# 18                                              Hausa    8.800000e+07
# 19                                              Tamil    8.700000e+07
# 20                        Yue Chinese(incl.Cantonese)    8.700000e+07
# 21                                            Swahili    8.700000e+07
# 22                                         Vietnamese    8.600000e+07
# 23                      Wu Chinese(incl.Shanghainese)    8.300000e+07
# 24                                         Tagalog[b]    8.300000e+07
# 25              Western Punjabi(excl.Eastern Punjabi)    8.200000e+07
# 26                                             Korean    8.100000e+07
# 27       Iranian Persian(excl.other Persian dialects)    7.800000e+07
# 28                                           Javanese    6.800000e+07
# 29                                            Italian    6.700000e+07
# 30                                           Gujarati    6.300000e+07
# 31                                               Thai    6.100000e+07
# 32                                            Amharic    6.000000e+07
# 33                                            Kannada    5.900000e+07
# 34       Levantine Arabic(excl.other Arabic dialects)    5.400000e+07
# 35                                           Bhojpuri    5.300000e+07
# 36                      Min Nan Chinese(incl.Hokkien)    5.100000e+07

# %% [markdown]
# ### B. Endangered languages dataset

# %%
# Drop the unnecessary columns
Endangered_df = all_endangered_lang_df.drop(columns=['Unnamed: 0', 'ID', 'Latitude', 'Longitude', 'Description of the location'])

# Display the DataFrame to check the changes
Endangered_df.head()
# Out:
#   Name in English                                          Countries  \
# 0   South Italian                                              Italy
# 1        Sicilian                                              Italy
# 2       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4         Lombard                                 Italy, Switzerland
#
#   Degree of endangerment  Number of speakers
# 0             Vulnerable           7500000.0
# 1             Vulnerable           5000000.0
# 2             Vulnerable           4800000.0
# 3             Vulnerable           4000000.0
# 4  Definitely endangered           3500000.0

# %%
# Save DataFrame to CSV

Endangered_df.to_csv('Resources/Endangered_Languages.csv', index=False)

# %%
# Rename the "Languages" column

Endangered_df.rename(columns={"Name in English": "Language"}, inplace=True)

#Check df changes

Endangered_df.head()
# Out:
#         Language                                          Countries  \
# 0  South Italian                                              Italy
# 1       Sicilian                                              Italy
# 2      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4        Lombard                                 Italy, Switzerland
#
#   Degree of endangerment  Number of speakers
# 0             Vulnerable           7500000.0
# 1             Vulnerable           5000000.0
# 2             Vulnerable           4800000.0
# 3             Vulnerable           4000000.0
# 4  Definitely endangered           3500000.0

# %%
# Fill Missing Values with an estimated  number 1000

Endangered_df["Number of speakers"] = Endangered_df["Number of speakers"].fillna(1000)

# Check df changes

Endangered_df.head()
# Out:
#         Language                                          Countries  \
# 0  South Italian                                              Italy
# 1       Sicilian                                              Italy
# 2      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4        Lombard                                 Italy, Switzerland
#
#   Degree of endangerment  Number of speakers
# 0             Vulnerable           7500000.0
# 1             Vulnerable           5000000.0
# 2             Vulnerable           4800000.0
# 3             Vulnerable           4000000.0
# 4  Definitely endangered           3500000.0

# %%
# Update endangerment labels to be consistent (lowercase, no extra spaces)

Endangered_df["Degree of endangerment"] = Endangered_df["Degree of endangerment"].str.strip().str.lower()

# Check df changes

Endangered_df.head()
# Out:
#         Language                                          Countries  \
# 0  South Italian                                              Italy
# 1       Sicilian                                              Italy
# 2      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4        Lombard                                 Italy, Switzerland
#
#   Degree of endangerment  Number of speakers
# 0             vulnerable           7500000.0
# 1             vulnerable           5000000.0
# 2             vulnerable           4800000.0
# 3             vulnerable           4000000.0
# 4  definitely endangered           3500000.0

# %%
#map categories to numerical values

endangerment_mapping = {
    "safe": 0,
    "vulnerable": 1,
    "definitely endangered": 2,
    "severely endangered": 3,
    "critically endangered": 4,
    "extinct": 5
}

Endangered_df["Endangerment Level"] = Endangered_df["Degree of endangerment"].map(endangerment_mapping)

# Check df changes

Endangered_df.head()
# Out:
#         Language                                          Countries  \
# 0  South Italian                                              Italy
# 1       Sicilian                                              Italy
# 2      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4        Lombard                                 Italy, Switzerland
#
#   Degree of endangerment  Number of speakers  Endangerment Level
# 0             vulnerable           7500000.0                   1
# 1             vulnerable           5000000.0                   1
# 2             vulnerable           4800000.0                   1
# 3             vulnerable           4000000.0                   1
# 4  definitely endangered           3500000.0                   2

# %%
# Clean Languages names by removing extra text inside parentheses

def clean_language_name(lang):
    return re.sub(r"\s*\(.*?\)", "", lang).strip()

Endangered_df["Language"] = Endangered_df["Language"].apply(clean_language_name)

# Check df changes

Endangered_df
# Out:
#            Language                                          Countries  \
# 0     South Italian                                              Italy
# 1          Sicilian                                              Italy
# 2         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4           Lombard                                 Italy, Switzerland
# ...             ...                                                ...
# 2717       Yonaguni                                              Japan
# 2718         Yucuna                                           Colombia
# 2719         Yurutí                                           Colombia
# 2720      Zangskari                                    India, Pakistan
# 2721        Zidgali                                               Oman
#
#      Degree of endangerment  Number of speakers  Endangerment Level
# 0                vulnerable           7500000.0                   1
# 1                vulnerable           5000000.0                   1
# 2                vulnerable           4800000.0                   1
# 3                vulnerable           4000000.0                   1
# 4     definitely endangered           3500000.0                   2
# ...                     ...                 ...                 ...
# 2717    severely endangered              1000.0                   3
# 2718  definitely endangered              1000.0                   2
# 2719  definitely endangered              1000.0                   2
# 2720  definitely endangered              1000.0                   2
# 2721  critically endangered              1000.0                   4
#
# [2722 rows x 5 columns]

# %%
# Convert to numeric, forcing errors to NaN

Endangered_df["Number of speakers"] = pd.to_numeric(Endangered_df["Number of speakers"], errors="coerce")

# Convert from float to int (after filling NaNs)

Endangered_df["Number of speakers"] = Endangered_df["Number of speakers"].fillna(0).astype(int)

# Check df changes

Endangered_df.head()
# Out:
#         Language                                          Countries  \
# 0  South Italian                                              Italy
# 1       Sicilian                                              Italy
# 2      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4        Lombard                                 Italy, Switzerland
#
#   Degree of endangerment  Number of speakers  Endangerment Level
# 0             vulnerable             7500000                   1
# 1             vulnerable             5000000                   1
# 2             vulnerable             4800000                   1
# 3             vulnerable             4000000                   1
# 4  definitely endangered             3500000                   2

# %%
# Convert to numeric, forcing errors to NaN

Endangered_df["Endangerment Level"] = pd.to_numeric(Endangered_df["Endangerment Level"], errors="coerce")

# Convert from float to int (after filling NaNs)

Endangered_df["Endangerment Level"] = Endangered_df["Endangerment Level"].fillna(0).astype(int)

# Check df changes

Endangered_df.head()
# Out:
#         Language                                          Countries  \
# 0  South Italian                                              Italy
# 1       Sicilian                                              Italy
# 2      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4        Lombard                                 Italy, Switzerland
#
#   Degree of endangerment  Number of speakers  Endangerment Level
# 0             vulnerable             7500000                   1
# 1             vulnerable             5000000                   1
# 2             vulnerable             4800000                   1
# 3             vulnerable             4000000                   1
# 4  definitely endangered             3500000                   2

# %%
# Check df characteristics

Endangered_df.info()
Endangered_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2722 entries, 0 to 2721
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Language                2722 non-null   object
#  1   Countries               2721 non-null   object
#  2   Degree of endangerment  2722 non-null   object
#  3   Number of speakers      2722 non-null   int32
#  4   Endangerment Level      2722 non-null   int32
# dtypes: int32(2), object(3)
# memory usage: 85.2+ KB
#         Language                                          Countries  \
# 0  South Italian                                              Italy
# 1       Sicilian                                              Italy
# 2      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4        Lombard                                 Italy, Switzerland
#
#   Degree of endangerment  Number of speakers  Endangerment Level
# 0             vulnerable             7500000                   1
# 1             vulnerable             5000000                   1
# 2             vulnerable             4800000                   1
# 3             vulnerable             4000000                   1
# 4  definitely endangered             3500000                   2

# %%
# Save the cleaned df in a new csv file

Endangered_df.to_csv('Resources/Speakers_per_Language.csv', index=False)

# %%
# Merge "widely_spoken_lan_df" and "Endangered_df", and store the merged dataset in a new df "df_languages"

df_languages = pd.merge(Endangered_df, widely_spoken_lan_df, on="Language", how="outer", suffixes=("_endangered", "_widely_spoken"))

# Check the new df 

df_languages
# Out:
#              Language                    Countries Degree of endangerment  \
# 0             !Gan!ne                 South Africa                extinct
# 1     A'ingae / Cofan                      Ecuador  definitely endangered
# 2     A'ingae / Cofan                     Colombia    severely endangered
# 3              A'tong                        India    severely endangered
# 4               Aasax  United Republic of Tanzania                extinct
# ...               ...                          ...                    ...
# 2754            ǁGana                     Botswana             vulnerable
# 2755          ǁKu ǁ'e                 South Africa                extinct
# 2756           ǁKx'au                 South Africa                extinct
# 2757           ǁXegwi                 South Africa                extinct
# 2758             ǂHoa                     Botswana  critically endangered
#
#       Number of speakers  Endangerment Level  Total_Speakers
# 0                    0.0                 5.0             NaN
# 1                  700.0                 2.0             NaN
# 2                  379.0                 3.0             NaN
# 3                 1000.0                 3.0             NaN
# 4                    0.0                 5.0             NaN
# ...                  ...                 ...             ...
# 2754              1550.0                 1.0             NaN
# 2755                 0.0                 5.0             NaN
# 2756                 0.0                 5.0             NaN
# 2757                 0.0                 5.0             NaN
# 2758               140.0                 4.0             NaN
#
# [2759 rows x 6 columns]

# %%
# Check if both columns are identical
df_languages["Duplicate_Columns"] = df_languages["Number of speakers"] == df_languages["Total_Speakers"]

# Count how many values are identical
df_languages["Duplicate_Columns"].value_counts()
# Out:
# Duplicate_Columns
# False    2759
# Name: count, dtype: int64

# %%
# Clear special characters from language column

def clean_language_name(name):
    return re.sub(r"[^\w\s]", "", str(name)).strip()

df_languages["Language"] = df_languages["Language"].apply(clean_language_name)

# Check df changes

df_languages
# Out:
#            Language                    Countries Degree of endangerment  \
# 0             Ganne                 South Africa                extinct
# 1     Aingae  Cofan                      Ecuador  definitely endangered
# 2     Aingae  Cofan                     Colombia    severely endangered
# 3             Atong                        India    severely endangered
# 4             Aasax  United Republic of Tanzania                extinct
# ...             ...                          ...                    ...
# 2754          ǁGana                     Botswana             vulnerable
# 2755         ǁKu ǁe                 South Africa                extinct
# 2756          ǁKxau                 South Africa                extinct
# 2757         ǁXegwi                 South Africa                extinct
# 2758           ǂHoa                     Botswana  critically endangered
#
#       Number of speakers  Endangerment Level  Total_Speakers  \
# 0                    0.0                 5.0             NaN
# 1                  700.0                 2.0             NaN
# 2                  379.0                 3.0             NaN
# 3                 1000.0                 3.0             NaN
# 4                    0.0                 5.0             NaN
# ...                  ...                 ...             ...
# 2754              1550.0                 1.0             NaN
# 2755                 0.0                 5.0             NaN
# 2756                 0.0                 5.0             NaN
# 2757                 0.0                 5.0             NaN
# 2758               140.0                 4.0             NaN
#
#       Duplicate_Columns
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 2754              False
# 2755              False
# 2756              False
# 2757              False
# 2758              False
#
# [2759 rows x 7 columns]

# %%
# Fill Missing Values with an estimated  number 1000, and copy clean values to Total_Speakers column

df_languages["Number of speakers"].fillna(1000)

df_languages["Total_Speakers"] = df_languages["Total_Speakers"].fillna(df_languages["Number of speakers"])

# Check df changes

df_languages
# Out:
#            Language                    Countries Degree of endangerment  \
# 0             Ganne                 South Africa                extinct
# 1     Aingae  Cofan                      Ecuador  definitely endangered
# 2     Aingae  Cofan                     Colombia    severely endangered
# 3             Atong                        India    severely endangered
# 4             Aasax  United Republic of Tanzania                extinct
# ...             ...                          ...                    ...
# 2754          ǁGana                     Botswana             vulnerable
# 2755         ǁKu ǁe                 South Africa                extinct
# 2756          ǁKxau                 South Africa                extinct
# 2757         ǁXegwi                 South Africa                extinct
# 2758           ǂHoa                     Botswana  critically endangered
#
#       Number of speakers  Endangerment Level  Total_Speakers  \
# 0                    0.0                 5.0             0.0
# 1                  700.0                 2.0           700.0
# 2                  379.0                 3.0           379.0
# 3                 1000.0                 3.0          1000.0
# 4                    0.0                 5.0             0.0
# ...                  ...                 ...             ...
# 2754              1550.0                 1.0          1550.0
# 2755                 0.0                 5.0             0.0
# 2756                 0.0                 5.0             0.0
# 2757                 0.0                 5.0             0.0
# 2758               140.0                 4.0           140.0
#
#       Duplicate_Columns
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 2754              False
# 2755              False
# 2756              False
# 2757              False
# 2758              False
#
# [2759 rows x 7 columns]

# %%
# Again and after merging the 2df, map categories to numerical values

endangerment_mapping = {
    "safe": 0,
    "vulnerable": 1,
    "definitely endangered": 2,
    "severely endangered": 3,
    "critically endangered": 4,
    "extinct": 5
}

df_languages["Endangerment Level"] = df_languages["Degree of endangerment"].map(endangerment_mapping)

# Check df changes

df_languages
# Out:
#            Language                    Countries Degree of endangerment  \
# 0             Ganne                 South Africa                extinct
# 1     Aingae  Cofan                      Ecuador  definitely endangered
# 2     Aingae  Cofan                     Colombia    severely endangered
# 3             Atong                        India    severely endangered
# 4             Aasax  United Republic of Tanzania                extinct
# ...             ...                          ...                    ...
# 2754          ǁGana                     Botswana             vulnerable
# 2755         ǁKu ǁe                 South Africa                extinct
# 2756          ǁKxau                 South Africa                extinct
# 2757         ǁXegwi                 South Africa                extinct
# 2758           ǂHoa                     Botswana  critically endangered
#
#       Number of speakers  Endangerment Level  Total_Speakers  \
# 0                    0.0                 5.0             0.0
# 1                  700.0                 2.0           700.0
# 2                  379.0                 3.0           379.0
# 3                 1000.0                 3.0          1000.0
# 4                    0.0                 5.0             0.0
# ...                  ...                 ...             ...
# 2754              1550.0                 1.0          1550.0
# 2755                 0.0                 5.0             0.0
# 2756                 0.0                 5.0             0.0
# 2757                 0.0                 5.0             0.0
# 2758               140.0                 4.0           140.0
#
#       Duplicate_Columns
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 2754              False
# 2755              False
# 2756              False
# 2757              False
# 2758              False
#
# [2759 rows x 7 columns]

# %%
# Clear again the special character after merging df

def clean_language_name(lang):
    return re.sub(r"[^a-zA-Z\s]", "", str(lang)).strip().lower()

df_languages["Language"] = df_languages["Language"].apply(clean_language_name)

# Check df changes

df_languages
# Out:
#            Language                    Countries Degree of endangerment  \
# 0             ganne                 South Africa                extinct
# 1     aingae  cofan                      Ecuador  definitely endangered
# 2     aingae  cofan                     Colombia    severely endangered
# 3             atong                        India    severely endangered
# 4             aasax  United Republic of Tanzania                extinct
# ...             ...                          ...                    ...
# 2754           gana                     Botswana             vulnerable
# 2755           ku e                 South Africa                extinct
# 2756           kxau                 South Africa                extinct
# 2757          xegwi                 South Africa                extinct
# 2758            hoa                     Botswana  critically endangered
#
#       Number of speakers  Endangerment Level  Total_Speakers  \
# 0                    0.0                 5.0             0.0
# 1                  700.0                 2.0           700.0
# 2                  379.0                 3.0           379.0
# 3                 1000.0                 3.0          1000.0
# 4                    0.0                 5.0             0.0
# ...                  ...                 ...             ...
# 2754              1550.0                 1.0          1550.0
# 2755                 0.0                 5.0             0.0
# 2756                 0.0                 5.0             0.0
# 2757                 0.0                 5.0             0.0
# 2758               140.0                 4.0           140.0
#
#       Duplicate_Columns
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 2754              False
# 2755              False
# 2756              False
# 2757              False
# 2758              False
#
# [2759 rows x 7 columns]

# %%
# Convert to numeric, forcing errors to NaN
df_languages["Total_Speakers"] = pd.to_numeric(df_languages["Total_Speakers"], errors="coerce")

# Convert from float to int (after filling NaNs)
df_languages["Total_Speakers"] = df_languages["Total_Speakers"].fillna(0).astype(int)

# Convert to numeric, forcing errors to NaN
df_languages["Number of speakers"] = pd.to_numeric(df_languages["Number of speakers"], errors="coerce")

# Convert from float to int (after filling NaNs)
df_languages["Number of speakers"] = df_languages["Number of speakers"].fillna(0).astype(int)

# Convert to numeric, forcing errors to NaN
df_languages["Endangerment Level"] = pd.to_numeric(df_languages["Endangerment Level"], errors="coerce")

# Convert from float to int (after filling NaNs)
df_languages["Endangerment Level"] = df_languages["Endangerment Level"].fillna(0).astype(int)

# %%
# Check df changes

df_languages
# Out:
#            Language                    Countries Degree of endangerment  \
# 0             ganne                 South Africa                extinct
# 1     aingae  cofan                      Ecuador  definitely endangered
# 2     aingae  cofan                     Colombia    severely endangered
# 3             atong                        India    severely endangered
# 4             aasax  United Republic of Tanzania                extinct
# ...             ...                          ...                    ...
# 2754           gana                     Botswana             vulnerable
# 2755           ku e                 South Africa                extinct
# 2756           kxau                 South Africa                extinct
# 2757          xegwi                 South Africa                extinct
# 2758            hoa                     Botswana  critically endangered
#
#       Number of speakers  Endangerment Level  Total_Speakers  \
# 0                      0                   5               0
# 1                    700                   2             700
# 2                    379                   3             379
# 3                   1000                   3            1000
# 4                      0                   5               0
# ...                  ...                 ...             ...
# 2754                1550                   1            1550
# 2755                   0                   5               0
# 2756                   0                   5               0
# 2757                   0                   5               0
# 2758                 140                   4             140
#
#       Duplicate_Columns
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 2754              False
# 2755              False
# 2756              False
# 2757              False
# 2758              False
#
# [2759 rows x 7 columns]

# %%
# Check for duplicate languages

duplicates = df_languages[df_languages.duplicated(subset=["Language", "Countries"], keep=False)]
print(duplicates)
# Out:
#        Language                 Countries Degree of endangerment  \
# 30         ainu        Russian Federation                extinct
# 31         ainu        Russian Federation                extinct
# 57        aleut  United States of America  critically endangered
# 58        aleut  United States of America    severely endangered
# 110     arapaho  United States of America    severely endangered
# ...         ...                       ...                    ...
# 2511        ute  United States of America    severely endangered
# 2512        ute  United States of America    severely endangered
# 2513        ute  United States of America    severely endangered
# 2617  winnebago  United States of America    severely endangered
# 2618  winnebago  United States of America    severely endangered
#
#       Number of speakers  Endangerment Level  Total_Speakers  \
# 30                     0                   5               0
# 31                     0                   5               0
# 57                   150                   4             150
# 58                   150                   3             150
# 110                 1000                   3            1000
# ...                  ...                 ...             ...
# 2511                 500                   3             500
# 2512                 300                   3             300
# 2513                 100                   3             100
# 2617                 250                   3             250
# 2618                 250                   3             250
#
#       Duplicate_Columns
# 30                False
# 31                False
# 57                False
# 58                False
# 110               False
# ...                 ...
# 2511              False
# 2512              False
# 2513              False
# 2617              False
# 2618              False
#
# [101 rows x 7 columns]

# %%
# Drop duplicate rows 

df_languages = df_languages.drop_duplicates(subset=["Language", "Countries"], keep="first")

# %%
# Check for duplicate one more time

duplicates = df_languages[df_languages.duplicated(subset=["Language", "Countries"], keep=False)]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Language, Countries, Degree of endangerment, Number of speakers, Endangerment Level, Total_Speakers, Duplicate_Columns]
# Index: []

# %%
# Check if both columns are identical
df_languages["Duplicate_Columns"] = df_languages["Number of speakers"] == df_languages["Total_Speakers"]

# Count how many values are identical
df_languages["Duplicate_Columns"].value_counts()
# Out:
# C:\Users\azerty\AppData\Local\Temp\ipykernel_21088\2495572796.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_languages["Duplicate_Columns"] = df_languages["Number of speakers"] == df_languages["Total_Speakers"]
# Duplicate_Columns
# True     2662
# False      37
# Name: count, dtype: int64

# %%
# Display rows where the values are different

df_languages[df_languages["Duplicate_Columns"] == False]
# Out:
#                                                Language Countries  \
# 71                                              amharic       NaN
# 263                                             bengali       NaN
# 275                                            bhojpuri       NaN
# 622            egyptian arabicexclother arabic dialects       NaN
# 636                         englishexclcreole languages       NaN
# 668                          frenchexclcreole languages       NaN
# 753                                            gujarati       NaN
# 786                                               hausa       NaN
# 801                                       hindiexclurdu       NaN
# 856                           indonesianexcl othermalay       NaN
# 867           iranian persianexclother persian dialects       NaN
# 881                                             italian       NaN
# 903                                            japanese       NaN
# 908                                            javanese       NaN
# 987                                             kannada       NaN
# 1145                                             korean       NaN
# 1281          levantine arabicexclother arabic dialects       NaN
# 1385  mandarin chineseinclstandard chinese but exclo...       NaN
# 1409                                            marathi       NaN
# 1470                         min nan chineseinclhokkien       NaN
# 1507                 modern standard arabicexcldialects       NaN
# 1664                                    nigerian pidgin       NaN
# 1922                     portugueseexclcreole languages       NaN
# 2027                                            russian       NaN
# 2222                        spanishexclcreole languages       NaN
# 2226                                    standard german       NaN
# 2241                                            swahili       NaN
# 2254                                           tagalogb       NaN
# 2287                                              tamil       NaN
# 2337                                             telugu       NaN
# 2358                                               thai       NaN
# 2456                                            turkish       NaN
# 2500                                      urduexclhindi       NaN
# 2527                                         vietnamese       NaN
# 2606                 western punjabiexcleastern punjabi       NaN
# 2628                         wu chineseinclshanghainese       NaN
# 2699                           yue chineseinclcantonese       NaN
#
#      Degree of endangerment  Number of speakers  Endangerment Level  \
# 71                      NaN                   0                   0
# 263                     NaN                   0                   0
# 275                     NaN                   0                   0
# 622                     NaN                   0                   0
# 636                     NaN                   0                   0
# 668                     NaN                   0                   0
# 753                     NaN                   0                   0
# 786                     NaN                   0                   0
# 801                     NaN                   0                   0
# 856                     NaN                   0                   0
# 867                     NaN                   0                   0
# 881                     NaN                   0                   0
# 903                     NaN                   0                   0
# 908                     NaN                   0                   0
# 987                     NaN                   0                   0
# 1145                    NaN                   0                   0
# 1281                    NaN                   0                   0
# 1385                    NaN                   0                   0
# 1409                    NaN                   0                   0
# 1470                    NaN                   0                   0
# 1507                    NaN                   0                   0
# 1664                    NaN                   0                   0
# 1922                    NaN                   0                   0
# 2027                    NaN                   0                   0
# 2222                    NaN                   0                   0
# 2226                    NaN                   0                   0
# 2241                    NaN                   0                   0
# 2254                    NaN                   0                   0
# 2287                    NaN                   0                   0
# 2337                    NaN                   0                   0
# 2358                    NaN                   0                   0
# 2456                    NaN                   0                   0
# 2500                    NaN                   0                   0
# 2527                    NaN                   0                   0
# 2606                    NaN                   0                   0
# 2628                    NaN                   0                   0
# 2699                    NaN                   0                   0
#
#       Total_Speakers  Duplicate_Columns
# 71          60000000              False
# 263        278000000              False
# 275         53000000              False
# 622        103000000              False
# 636       1515000000              False
# 668        312000000              False
# 753         63000000              False
# 786         88000000              False
# 801        609000000              False
# 856        199000000              False
# 867         78000000              False
# 881         67000000              False
# 903        123000000              False
# 908         68000000              False
# 987         59000000              False
# 1145        81000000              False
# 1281        54000000              False
# 1385      1140000000              False
# 1409        99000000              False
# 1470        51000000              False
# 1507       332000000              False
# 1664       121000000              False
# 1922       264000000              False
# 2027       255000000              False
# 2222       560000000              False
# 2226       134000000              False
# 2241        87000000              False
# 2254        83000000              False
# 2287        87000000              False
# 2337        96000000              False
# 2358        61000000              False
# 2456        90000000              False
# 2500       238000000              False
# 2527        86000000              False
# 2606        82000000              False
# 2628        83000000              False
# 2699        87000000              False

# %%
# Drop rows where the values are different

df_languages = df_languages[df_languages["Duplicate_Columns"]]
df_languages
# Out:
#            Language                    Countries Degree of endangerment  \
# 0             ganne                 South Africa                extinct
# 1     aingae  cofan                      Ecuador  definitely endangered
# 2     aingae  cofan                     Colombia    severely endangered
# 3             atong                        India    severely endangered
# 4             aasax  United Republic of Tanzania                extinct
# ...             ...                          ...                    ...
# 2754           gana                     Botswana             vulnerable
# 2755           ku e                 South Africa                extinct
# 2756           kxau                 South Africa                extinct
# 2757          xegwi                 South Africa                extinct
# 2758            hoa                     Botswana  critically endangered
#
#       Number of speakers  Endangerment Level  Total_Speakers  \
# 0                      0                   5               0
# 1                    700                   2             700
# 2                    379                   3             379
# 3                   1000                   3            1000
# 4                      0                   5               0
# ...                  ...                 ...             ...
# 2754                1550                   1            1550
# 2755                   0                   5               0
# 2756                   0                   5               0
# 2757                   0                   5               0
# 2758                 140                   4             140
#
#       Duplicate_Columns
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ...                 ...
# 2754               True
# 2755               True
# 2756               True
# 2757               True
# 2758               True
#
# [2662 rows x 7 columns]

# %%
# Store them in a new df

df_different_values = df_languages[df_languages["Duplicate_Columns"] == False]

df_different_values.to_csv("Resources/different_values.csv", index=False)

# %%
# Read the clean dataset of updated different values

df_different_values_modified = pd.read_csv("Resources/Man_modif_widely_spoken_lang.csv")

df_different_values_modified.head()
# Out:
#    Language   Countries Degree of endangerment  Number of speakers  \
# 0   amharic    Ethiopia                   Safe            60000000
# 1    arabic        Many                   Safe           435000000
# 2   bengali  Bangladesh                   Safe           278000000
# 3  bhojpuri       India                   Safe            53000000
# 4   chinese       China                   Safe          1361000000
#
#    Total_Speakers  Duplicate_Columns  Endangerment_Level
# 0        60000000              False                   0
# 1       435000000              False                   0
# 2       278000000              False                   0
# 3        53000000              False                   0
# 4      1361000000              False                   0

# %%
# Concatenate corrected and initial dataframes

df_languages_final = pd.concat([df_languages, df_different_values_modified], ignore_index=True)

# %%
# Compare content of columns "Number of speakers" and "Total_Speakers"

if df_languages_final['Number of speakers'].equals(df_languages_final['Total_Speakers']):
    print("The columns have exactly the same data.")
else:
    print("The columns do not have the same data.")
# Out:
# The columns have exactly the same data.

# %%
# Save the final dataset

df_languages_final.to_csv("Resources/df_language_final.csv", index=False)
